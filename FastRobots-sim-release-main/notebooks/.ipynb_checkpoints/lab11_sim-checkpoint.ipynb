# %% [markdown]
# # Lab 11: Grid Localization using Bayes Filter (Virtual Robot)
#
# ### <span style="color:rgb(0,150,0)">It is recommended that you close any heavy-duty applications running on your system while working on this lab.</span>
#
# <hr>

# %%
# %load_ext autoreload
# %autoreload 2

import traceback
from notebook_utils import *
from Traj import *
import asyncio
from localization_extras import Localization

# Setup Logger
LOG = get_logger('demo_notebook.log')

# Init GUI and Commander
gui = GET_GUI()
cmdr = gui.launcher.commander

gui.show()

# Start the simulator
START_SIM()

# Start the plotter
START_PLOTTER()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2026-04-22 13:09:45,178 | INFO     |: Logger demo_notebook.log already initialized.
# 2026-04-22 13:09:45,178 | INFO     |: GUI is already running. Shutdown notebook to force restart the GUI.
# TwoByTwoLayout(children=(Label(value='Simulator', layout=Layout(grid_area='top-left', width='80px')), HBox(chi…
# 2026-04-22 13:09:45,181 | INFO     |: Creating New Simulator Process
# /Users/donghaohong/Documents/FastRobots_ble/lib/python3.12/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# 2026-04-22 13:09:45,793 | INFO     |: Creating New Plotter Process

# %%
# Initialize Robot to communicate with the virtual robot and plotter
robot = VirtualRobot(cmdr)

# Initialize mapper
# Requires a VirtualRobot object as a parameter
mapper = Mapper(robot)

# Initialize your BaseLocalization object
# Requires a VirtualRobot object and a Mapper object as parameters
loc = Localization(robot, mapper)

## Plot Map
cmdr.plot_map()
# Out:
# 2026-04-22 13:09:49,776 | INFO     |:  | Number of observations per grid cell: 18
# 2026-04-22 13:09:49,777 | INFO     |:  | Precaching Views...
# 2026-04-22 13:09:50,681 | INFO     |:  | Precaching Time: 0.903 secs
# 2026-04-22 13:09:50,681 | INFO     |: Initializing beliefs with a Uniform Distribution
# 2026-04-22 13:09:50,682 | INFO     |: Uniform Belief with each cell value: 0.00051440329218107

# %%
# Start the simulator
STOP_SIM()

# Start the plotter
STOP_PLOTTER()
# Out:
# 2026-04-22 13:11:57,136 | ERROR    |: Simulator is not running
# 2026-04-22 13:11:57,137 | INFO     |: Plotter is stopped

# %% [markdown]
# # Run the Bayes Filter
# The cells below utilizes the member functions of class **Localization** (defined in [localization_extras.py](../localization_extras.py)) in each iteration of the Bayes filter algorithm to localize the robot in the grid map. <br>

# %%
# Reset Robot and Plots
robot.reset()
cmdr.reset_plotter()

# Init Uniform Belief
loc.init_grid_beliefs()

# Get Observation Data by executing a 360 degree rotation motion
loc.get_observation_data()

# Run Update Step
loc.update_step()
loc.print_update_stats(plot_data=True)

# Plot Odom and GT
current_odom, current_gt = robot.get_pose()
cmdr.plot_gt(current_gt[0], current_gt[1])
cmdr.plot_odom(current_odom[0], current_odom[1])
# Out:
# 2026-04-22 13:09:55,166 | INFO     |: Initializing beliefs with a Uniform Distribution
# 2026-04-22 13:09:55,166 | INFO     |: Uniform Belief with each cell value: 0.00051440329218107
# 2026-04-22 13:09:58,144 | INFO     |: Update Step
# 2026-04-22 13:09:58,145 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:09:58,146 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:09:58,155 | INFO     |: GT index      : (6, 4, 9)
# 2026-04-22 13:09:58,155 | INFO     |: Bel index     : (np.int64(5), np.int64(4), np.int64(9)) with prob = 0.8674340
# 2026-04-22 13:09:58,155 | INFO     |: Bel_bar prob at index = 0.00051440329218107
# 2026-04-22 13:09:58,156 | INFO     |: GT            : (0.000, 0.000, 360.000)
# 2026-04-22 13:09:58,156 | INFO     |: Belief        : (0.000, 0.000, 10.000)
# 2026-04-22 13:09:58,156 | INFO     |: POS ERROR     : (-0.000, -0.000, 350.000)
# 2026-04-22 13:09:58,156 | INFO     |: ---------- UPDATE STATS -----------

# %%
# Initialize the Trajectory object
traj = Trajectory(loc)

# Run through each motion steps
for t in range(0, traj.total_time_steps):
    print("\n\n-----------------", t, "-----------------")
    
    prev_odom, current_odom, prev_gt, current_gt = traj.execute_time_step(t)
        
    # Prediction Step
    loc.prediction_step(current_odom, prev_odom)
    loc.print_prediction_stats(plot_data=True)
    
    # Get Observation Data by executing a 360 degree rotation motion
    loc.get_observation_data()
    
    # Update Step
    loc.update_step()
    loc.print_update_stats(plot_data=True)

# Uncomment the below line to wait for keyboard input between each iteration.
#   input("Press Enter to Continue")
        
    print("-------------------------------------")
# Out:
# ----------------- 0 -----------------
# 2026-04-22 13:10:10,203 | INFO     |: Prediction Step
# 2026-04-22 13:10:10,222 | INFO     |:  | Prediction Time: 0.018 secs
# 2026-04-22 13:10:10,222 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:10,237 | INFO     |: GT index         : (6, 3, 7)
# 2026-04-22 13:10:10,237 | INFO     |: Prior Bel index  : (np.int64(8), np.int64(5), np.int64(8)) with prob = 0.0705766
# 2026-04-22 13:10:10,237 | INFO     |: POS ERROR        : (-0.633, -0.392, -29.725)
# 2026-04-22 13:10:10,238 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:13,199 | INFO     |: Update Step
# 2026-04-22 13:10:13,200 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:10:13,200 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:10:13,210 | INFO     |: GT index      : (6, 3, 7)
# 2026-04-22 13:10:13,211 | INFO     |: Bel index     : (np.int64(6), np.int64(4), np.int64(6)) with prob = 0.9999999
# 2026-04-22 13:10:13,211 | INFO     |: Bel_bar prob at index = 0.009936720489170856
# 2026-04-22 13:10:13,211 | INFO     |: GT            : (0.282, -0.087, 320.275)
# 2026-04-22 13:10:13,211 | INFO     |: Belief        : (0.305, 0.000, -50.000)
# 2026-04-22 13:10:13,212 | INFO     |: POS ERROR     : (-0.023, -0.087, 370.275)
# 2026-04-22 13:10:13,212 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 1 -----------------
# 2026-04-22 13:10:15,256 | INFO     |: Prediction Step
# 2026-04-22 13:10:15,268 | INFO     |:  | Prediction Time: 0.012 secs
# 2026-04-22 13:10:15,268 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:15,272 | INFO     |: GT index         : (7, 2, 5)
# 2026-04-22 13:10:15,272 | INFO     |: Prior Bel index  : (np.int64(5), np.int64(1), np.int64(5)) with prob = 0.0722292
# 2026-04-22 13:10:15,273 | INFO     |: POS ERROR        : (0.496, 0.413, 367.357)
# 2026-04-22 13:10:15,273 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:19,236 | INFO     |: Update Step
# 2026-04-22 13:10:19,237 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:10:19,237 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:10:19,238 | INFO     |: GT index      : (7, 2, 5)
# 2026-04-22 13:10:19,238 | INFO     |: Bel index     : (np.int64(6), np.int64(2), np.int64(5)) with prob = 1.0
# 2026-04-22 13:10:19,238 | INFO     |: Bel_bar prob at index = 0.04268723350537923
# 2026-04-22 13:10:19,239 | INFO     |: GT            : (0.508, -0.524, 657.357)
# 2026-04-22 13:10:19,239 | INFO     |: Belief        : (0.305, -0.610, -70.000)
# 2026-04-22 13:10:19,239 | INFO     |: POS ERROR     : (0.203, 0.086, 727.357)
# 2026-04-22 13:10:19,239 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 2 -----------------
# 2026-04-22 13:10:20,292 | INFO     |: Prediction Step
# 2026-04-22 13:10:20,302 | INFO     |:  | Prediction Time: 0.010 secs
# 2026-04-22 13:10:20,303 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:20,310 | INFO     |: GT index         : (7, 2, 4)
# 2026-04-22 13:10:20,310 | INFO     |: Prior Bel index  : (np.int64(5), np.int64(2), np.int64(4)) with prob = 0.1711648
# 2026-04-22 13:10:20,310 | INFO     |: POS ERROR        : (0.508, 0.086, 724.437)
# 2026-04-22 13:10:20,310 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:23,299 | INFO     |: Update Step
# 2026-04-22 13:10:23,300 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:10:23,300 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:10:23,313 | INFO     |: GT index      : (7, 2, 4)
# 2026-04-22 13:10:23,313 | INFO     |: Bel index     : (np.int64(6), np.int64(2), np.int64(4)) with prob = 1.0
# 2026-04-22 13:10:23,313 | INFO     |: Bel_bar prob at index = 4.121544369087537e-59
# 2026-04-22 13:10:23,314 | INFO     |: GT            : (0.508, -0.524, 994.437)
# 2026-04-22 13:10:23,314 | INFO     |: Belief        : (0.305, -0.610, -90.000)
# 2026-04-22 13:10:23,314 | INFO     |: POS ERROR     : (0.203, 0.086, 1084.437)
# 2026-04-22 13:10:23,314 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 3 -----------------
# 2026-04-22 13:10:24,366 | INFO     |: Prediction Step
# 2026-04-22 13:10:24,375 | INFO     |:  | Prediction Time: 0.009 secs
# 2026-04-22 13:10:24,376 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:24,381 | INFO     |: GT index         : (7, 1, 4)
# 2026-04-22 13:10:24,381 | INFO     |: Prior Bel index  : (np.int64(7), np.int64(0), np.int64(4)) with prob = 0.1992187
# 2026-04-22 13:10:24,381 | INFO     |: POS ERROR        : (-0.072, 0.316, 1084.437)
# 2026-04-22 13:10:24,382 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:27,369 | INFO     |: Update Step
# 2026-04-22 13:10:27,370 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:10:27,371 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:10:27,387 | INFO     |: GT index      : (7, 0, 4)
# 2026-04-22 13:10:27,387 | INFO     |: Bel index     : (np.int64(7), np.int64(1), np.int64(4)) with prob = 1.0
# 2026-04-22 13:10:27,387 | INFO     |: Bel_bar prob at index = 0.011110713569346382
# 2026-04-22 13:10:27,387 | INFO     |: GT            : (0.539, -0.923, 1354.437)
# 2026-04-22 13:10:27,388 | INFO     |: Belief        : (0.610, -0.914, -90.000)
# 2026-04-22 13:10:27,388 | INFO     |: POS ERROR     : (-0.071, -0.008, 1444.437)
# 2026-04-22 13:10:27,388 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 4 -----------------
# 2026-04-22 13:10:30,435 | INFO     |: Prediction Step
# 2026-04-22 13:10:30,445 | INFO     |:  | Prediction Time: 0.009 secs
# 2026-04-22 13:10:30,445 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:30,453 | INFO     |: GT index         : (8, 0, 8)
# 2026-04-22 13:10:30,453 | INFO     |: Prior Bel index  : (np.int64(5), np.int64(0), np.int64(12)) with prob = 0.1620575
# 2026-04-22 13:10:30,453 | INFO     |: POS ERROR        : (0.796, 0.153, 1368.947)
# 2026-04-22 13:10:30,453 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:33,447 | INFO     |: Update Step
# 2026-04-22 13:10:33,448 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:10:33,448 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:10:33,464 | INFO     |: GT index      : (8, 0, 8)
# 2026-04-22 13:10:33,464 | INFO     |: Bel index     : (np.int64(6), np.int64(1), np.int64(8)) with prob = 0.9999993
# 2026-04-22 13:10:33,464 | INFO     |: Bel_bar prob at index = 0.0005136664345644787
# 2026-04-22 13:10:33,464 | INFO     |: GT            : (0.796, -1.067, 1798.947)
# 2026-04-22 13:10:33,465 | INFO     |: Belief        : (0.305, -0.914, -10.000)
# 2026-04-22 13:10:33,465 | INFO     |: POS ERROR     : (0.491, -0.152, 1808.947)
# 2026-04-22 13:10:33,465 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 5 -----------------
# 2026-04-22 13:10:39,523 | INFO     |: Prediction Step
# 2026-04-22 13:10:39,533 | INFO     |:  | Prediction Time: 0.009 secs
# 2026-04-22 13:10:39,533 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:39,539 | INFO     |: GT index         : (11, 0, 11)
# 2026-04-22 13:10:39,539 | INFO     |: Prior Bel index  : (np.int64(7), np.int64(0), np.int64(9)) with prob = 0.2215037
# 2026-04-22 13:10:39,540 | INFO     |: POS ERROR        : (0.961, 0.293, 1837.503)
# 2026-04-22 13:10:39,540 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:42,503 | INFO     |: Update Step
# 2026-04-22 13:10:42,503 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:10:42,504 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:10:42,518 | INFO     |: GT index      : (11, 0, 11)
# 2026-04-22 13:10:42,519 | INFO     |: Bel index     : (np.int64(10), np.int64(1), np.int64(11)) with prob = 1.0
# 2026-04-22 13:10:42,519 | INFO     |: Bel_bar prob at index = 0.002973443776365673
# 2026-04-22 13:10:42,519 | INFO     |: GT            : (1.570, -0.926, 2207.818)
# 2026-04-22 13:10:42,520 | INFO     |: Belief        : (1.524, -0.914, 50.000)
# 2026-04-22 13:10:42,520 | INFO     |: POS ERROR     : (0.046, -0.011, 2157.818)
# 2026-04-22 13:10:42,520 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 6 -----------------
# 2026-04-22 13:10:44,573 | INFO     |: Prediction Step
# 2026-04-22 13:10:44,583 | INFO     |:  | Prediction Time: 0.009 secs
# 2026-04-22 13:10:44,583 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:44,590 | INFO     |: GT index         : (11, 2, 12)
# 2026-04-22 13:10:44,591 | INFO     |: Prior Bel index  : (np.int64(11), np.int64(3), np.int64(12)) with prob = 0.1018000
# 2026-04-22 13:10:44,591 | INFO     |: POS ERROR        : (-0.167, -0.252, 2165.995)
# 2026-04-22 13:10:44,591 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:47,565 | INFO     |: Update Step
# 2026-04-22 13:10:47,566 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:10:47,566 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:10:47,576 | INFO     |: GT index      : (11, 2, 12)
# 2026-04-22 13:10:47,576 | INFO     |: Bel index     : (np.int64(11), np.int64(3), np.int64(13)) with prob = 1.0
# 2026-04-22 13:10:47,576 | INFO     |: Bel_bar prob at index = 0.095591701673783
# 2026-04-22 13:10:47,577 | INFO     |: GT            : (1.667, -0.538, 2595.995)
# 2026-04-22 13:10:47,577 | INFO     |: Belief        : (1.829, -0.305, 90.000)
# 2026-04-22 13:10:47,577 | INFO     |: POS ERROR     : (-0.162, -0.233, 2505.995)
# 2026-04-22 13:10:47,577 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 7 -----------------
# 2026-04-22 13:10:49,631 | INFO     |: Prediction Step
# 2026-04-22 13:10:49,641 | INFO     |:  | Prediction Time: 0.009 secs
# 2026-04-22 13:10:49,641 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:49,647 | INFO     |: GT index         : (11, 3, 13)
# 2026-04-22 13:10:49,647 | INFO     |: Prior Bel index  : (np.int64(11), np.int64(5), np.int64(13)) with prob = 0.1096378
# 2026-04-22 13:10:49,647 | INFO     |: POS ERROR        : (-0.076, -0.499, 2511.630)
# 2026-04-22 13:10:49,648 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:52,621 | INFO     |: Update Step
# 2026-04-22 13:10:52,621 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:10:52,622 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:10:52,637 | INFO     |: GT index      : (11, 3, 13)
# 2026-04-22 13:10:52,637 | INFO     |: Bel index     : (np.int64(11), np.int64(3), np.int64(13)) with prob = 1.0
# 2026-04-22 13:10:52,637 | INFO     |: Bel_bar prob at index = 2.4867752222078385e-16
# 2026-04-22 13:10:52,637 | INFO     |: GT            : (1.753, -0.194, 2961.630)
# 2026-04-22 13:10:52,638 | INFO     |: Belief        : (1.829, -0.305, 90.000)
# 2026-04-22 13:10:52,638 | INFO     |: POS ERROR     : (-0.076, 0.111, 2871.630)
# 2026-04-22 13:10:52,638 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 8 -----------------
# 2026-04-22 13:10:55,687 | INFO     |: Prediction Step
# 2026-04-22 13:10:55,696 | INFO     |:  | Prediction Time: 0.010 secs
# 2026-04-22 13:10:55,697 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:55,704 | INFO     |: GT index         : (11, 4, 14)
# 2026-04-22 13:10:55,704 | INFO     |: Prior Bel index  : (np.int64(10), np.int64(5), np.int64(13)) with prob = 0.0922689
# 2026-04-22 13:10:55,704 | INFO     |: POS ERROR        : (0.251, -0.008, 2893.980)
# 2026-04-22 13:10:55,705 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:10:58,672 | INFO     |: Update Step
# 2026-04-22 13:10:58,673 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:10:58,673 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:10:58,683 | INFO     |: GT index      : (11, 4, 14)
# 2026-04-22 13:10:58,684 | INFO     |: Bel index     : (np.int64(11), np.int64(4), np.int64(13)) with prob = 0.9991962
# 2026-04-22 13:10:58,684 | INFO     |: Bel_bar prob at index = 0.0007088300063406448
# 2026-04-22 13:10:58,684 | INFO     |: GT            : (1.775, 0.297, 3343.980)
# 2026-04-22 13:10:58,684 | INFO     |: Belief        : (1.829, 0.000, 90.000)
# 2026-04-22 13:10:58,685 | INFO     |: POS ERROR     : (-0.054, 0.297, 3253.980)
# 2026-04-22 13:10:58,685 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 9 -----------------
# 2026-04-22 13:11:01,745 | INFO     |: Prediction Step
# 2026-04-22 13:11:01,764 | INFO     |:  | Prediction Time: 0.019 secs
# 2026-04-22 13:11:01,764 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:11:01,780 | INFO     |: GT index         : (11, 6, 16)
# 2026-04-22 13:11:01,780 | INFO     |: Prior Bel index  : (np.int64(11), np.int64(4), np.int64(15)) with prob = 0.5082994
# 2026-04-22 13:11:01,780 | INFO     |: POS ERROR        : (-0.037, 0.621, 3252.459)
# 2026-04-22 13:11:01,780 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:11:04,755 | INFO     |: Update Step
# 2026-04-22 13:11:04,756 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:11:04,756 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:11:04,768 | INFO     |: GT index      : (11, 6, 16)
# 2026-04-22 13:11:04,768 | INFO     |: Bel index     : (np.int64(11), np.int64(7), np.int64(16)) with prob = 1.0
# 2026-04-22 13:11:04,768 | INFO     |: Bel_bar prob at index = 1.6954043437278262e-15
# 2026-04-22 13:11:04,768 | INFO     |: GT            : (1.792, 0.621, 3743.414)
# 2026-04-22 13:11:04,768 | INFO     |: Belief        : (1.829, 0.914, 150.000)
# 2026-04-22 13:11:04,769 | INFO     |: POS ERROR     : (-0.037, -0.293, 3593.414)
# 2026-04-22 13:11:04,769 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 10 -----------------
# 2026-04-22 13:11:06,812 | INFO     |: Prediction Step
# 2026-04-22 13:11:06,822 | INFO     |:  | Prediction Time: 0.010 secs
# 2026-04-22 13:11:06,823 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:11:06,830 | INFO     |: GT index         : (10, 7, 16)
# 2026-04-22 13:11:06,830 | INFO     |: Prior Bel index  : (np.int64(10), np.int64(6), np.int64(16)) with prob = 0.1657492
# 2026-04-22 13:11:06,830 | INFO     |: POS ERROR        : (-0.134, 0.309, 3603.920)
# 2026-04-22 13:11:06,831 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:11:09,821 | INFO     |: Update Step
# 2026-04-22 13:11:09,822 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:11:09,822 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:11:09,832 | INFO     |: GT index      : (10, 7, 16)
# 2026-04-22 13:11:09,832 | INFO     |: Bel index     : (np.int64(10), np.int64(6), np.int64(16)) with prob = 1.0
# 2026-04-22 13:11:09,833 | INFO     |: Bel_bar prob at index = 0.16574929629190324
# 2026-04-22 13:11:09,833 | INFO     |: GT            : (1.390, 0.919, 4114.494)
# 2026-04-22 13:11:09,833 | INFO     |: Belief        : (1.524, 0.610, 150.000)
# 2026-04-22 13:11:09,834 | INFO     |: POS ERROR     : (-0.134, 0.309, 3964.494)
# 2026-04-22 13:11:09,834 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 11 -----------------
# 2026-04-22 13:11:12,890 | INFO     |: Prediction Step
# 2026-04-22 13:11:12,900 | INFO     |:  | Prediction Time: 0.010 secs
# 2026-04-22 13:11:12,900 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:11:12,907 | INFO     |: GT index         : (7, 6, 3)
# 2026-04-22 13:11:12,907 | INFO     |: Prior Bel index  : (np.int64(8), np.int64(5), np.int64(3)) with prob = 0.1290612
# 2026-04-22 13:11:12,907 | INFO     |: POS ERROR        : (-0.393, 0.567, 4320.732)
# 2026-04-22 13:11:12,908 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:11:15,897 | INFO     |: Update Step
# 2026-04-22 13:11:15,898 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:11:15,898 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:11:15,909 | INFO     |: GT index      : (7, 6, 3)
# 2026-04-22 13:11:15,910 | INFO     |: Bel index     : (np.int64(7), np.int64(7), np.int64(3)) with prob = 1.0
# 2026-04-22 13:11:15,910 | INFO     |: Bel_bar prob at index = 2.806521106551928e-06
# 2026-04-22 13:11:15,910 | INFO     |: GT            : (0.522, 0.871, 4570.732)
# 2026-04-22 13:11:15,910 | INFO     |: Belief        : (0.610, 0.914, -110.000)
# 2026-04-22 13:11:15,911 | INFO     |: POS ERROR     : (-0.088, -0.043, 4680.732)
# 2026-04-22 13:11:15,911 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 12 -----------------
# 2026-04-22 13:11:17,967 | INFO     |: Prediction Step
# 2026-04-22 13:11:17,976 | INFO     |:  | Prediction Time: 0.009 secs
# 2026-04-22 13:11:17,977 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:11:17,984 | INFO     |: GT index         : (7, 4, 5)
# 2026-04-22 13:11:17,984 | INFO     |: Prior Bel index  : (np.int64(8), np.int64(5), np.int64(7)) with prob = 0.1175467
# 2026-04-22 13:11:17,984 | INFO     |: POS ERROR        : (-0.607, -0.047, 4643.522)
# 2026-04-22 13:11:17,985 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:11:20,963 | INFO     |: Update Step
# 2026-04-22 13:11:20,964 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:11:20,964 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:11:20,976 | INFO     |: GT index      : (7, 4, 5)
# 2026-04-22 13:11:20,976 | INFO     |: Bel index     : (np.int64(6), np.int64(5), np.int64(5)) with prob = 1.0
# 2026-04-22 13:11:20,976 | INFO     |: Bel_bar prob at index = 0.0009920526192707304
# 2026-04-22 13:11:20,977 | INFO     |: GT            : (0.307, 0.258, 4975.815)
# 2026-04-22 13:11:20,977 | INFO     |: Belief        : (0.305, 0.305, -70.000)
# 2026-04-22 13:11:20,977 | INFO     |: POS ERROR     : (0.002, -0.047, 5045.815)
# 2026-04-22 13:11:20,977 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 13 -----------------
# 2026-04-22 13:11:23,033 | INFO     |: Prediction Step
# 2026-04-22 13:11:23,043 | INFO     |:  | Prediction Time: 0.009 secs
# 2026-04-22 13:11:23,043 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:11:23,050 | INFO     |: GT index         : (6, 3, 2)
# 2026-04-22 13:11:23,051 | INFO     |: Prior Bel index  : (np.int64(7), np.int64(3), np.int64(2)) with prob = 0.1210240
# 2026-04-22 13:11:23,051 | INFO     |: POS ERROR        : (-0.566, 0.279, 5037.071)
# 2026-04-22 13:11:23,051 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:11:26,037 | INFO     |: Update Step
# 2026-04-22 13:11:26,038 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:11:26,038 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:11:26,054 | INFO     |: GT index      : (6, 3, 2)
# 2026-04-22 13:11:26,054 | INFO     |: Bel index     : (np.int64(5), np.int64(3), np.int64(2)) with prob = 0.9999998
# 2026-04-22 13:11:26,054 | INFO     |: Bel_bar prob at index = 7.421801209828667e-07
# 2026-04-22 13:11:26,054 | INFO     |: GT            : (0.039, -0.030, 5267.072)
# 2026-04-22 13:11:26,055 | INFO     |: Belief        : (0.000, -0.305, -130.000)
# 2026-04-22 13:11:26,055 | INFO     |: POS ERROR     : (0.039, 0.275, 5397.072)
# 2026-04-22 13:11:26,055 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 14 -----------------
# 2026-04-22 13:11:29,111 | INFO     |: Prediction Step
# 2026-04-22 13:11:29,121 | INFO     |:  | Prediction Time: 0.009 secs
# 2026-04-22 13:11:29,121 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:11:29,129 | INFO     |: GT index         : (4, 3, 1)
# 2026-04-22 13:11:29,129 | INFO     |: Prior Bel index  : (np.int64(4), np.int64(5), np.int64(2)) with prob = 0.0864766
# 2026-04-22 13:11:29,129 | INFO     |: POS ERROR        : (-0.029, -0.459, 5374.053)
# 2026-04-22 13:11:29,129 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:11:32,128 | INFO     |: Update Step
# 2026-04-22 13:11:32,129 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:11:32,129 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:11:32,142 | INFO     |: GT index      : (4, 3, 1)
# 2026-04-22 13:11:32,142 | INFO     |: Bel index     : (np.int64(4), np.int64(3), np.int64(1)) with prob = 1.0
# 2026-04-22 13:11:32,143 | INFO     |: Bel_bar prob at index = 9.51800044219676e-13
# 2026-04-22 13:11:32,143 | INFO     |: GT            : (-0.334, -0.155, 5604.053)
# 2026-04-22 13:11:32,143 | INFO     |: Belief        : (-0.305, -0.305, -150.000)
# 2026-04-22 13:11:32,143 | INFO     |: POS ERROR     : (-0.029, 0.150, 5754.053)
# 2026-04-22 13:11:32,144 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
#
#
# ----------------- 15 -----------------
# 2026-04-22 13:11:35,195 | INFO     |: Prediction Step
# 2026-04-22 13:11:35,205 | INFO     |:  | Prediction Time: 0.010 secs
# 2026-04-22 13:11:35,205 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:11:35,211 | INFO     |: GT index         : (3, 3, 0)
# 2026-04-22 13:11:35,212 | INFO     |: Prior Bel index  : (np.int64(3), np.int64(2), np.int64(1)) with prob = 0.1010782
# 2026-04-22 13:11:35,212 | INFO     |: POS ERROR        : (-0.110, 0.486, 5730.939)
# 2026-04-22 13:11:35,212 | INFO     |: ---------- PREDICTION STATS -----------
# 2026-04-22 13:11:38,207 | INFO     |: Update Step
# 2026-04-22 13:11:38,208 | INFO     |:      | Update Time: 0.001 secs
# 2026-04-22 13:11:38,209 | INFO     |: ---------- UPDATE STATS -----------
# 2026-04-22 13:11:38,221 | INFO     |: GT index      : (3, 3, 0)
# 2026-04-22 13:11:38,221 | INFO     |: Bel index     : (np.int64(3), np.int64(3), np.int64(0)) with prob = 0.9964563
# 2026-04-22 13:11:38,221 | INFO     |: Bel_bar prob at index = 0.00017180415121347857
# 2026-04-22 13:11:38,221 | INFO     |: GT            : (-0.719, -0.124, 5941.035)
# 2026-04-22 13:11:38,222 | INFO     |: Belief        : (-0.610, -0.305, -170.000)
# 2026-04-22 13:11:38,222 | INFO     |: POS ERROR     : (-0.110, 0.181, 6111.035)
# 2026-04-22 13:11:38,222 | INFO     |: ---------- UPDATE STATS -----------
# -------------------------------------
# Traceback (most recent call last):
#   File "/Users/donghaohong/Documents/ble_robot_1.4/FastRobots-sim-release-main/src/plotter.py", line 263, in keyPressEvent
#     if event.key() == Qt.Key_Escape:
#                       ^^^^^^^^^^^^^
# AttributeError: type object 'Qt' has no attribute 'Key_Escape'
# 2026-04-22 13:11:41.893 Python[30698:2093219] error messaging the mach port for IMKCFRunLoopWakeUpReliable
# Traceback (most recent call last):
#   File "/Users/donghaohong/Documents/ble_robot_1.4/FastRobots-sim-release-main/src/plotter.py", line 252, in closeEvent
#     result = QtGui.QMessageBox.question(self,
#              ^^^^^^^^^^^^^^^^^
# AttributeError: module 'pyqtgraph.Qt.QtGui' has no attribute 'QMessageBox'
# Loading Flatland...
# Initializing pygame framework...
