# %%
# %load_ext autoreload
# %autoreload 2

from ble import get_ble_controller
from base_ble import LOG
from cmd_types import CMD
import time
import numpy as np

LOG.propagate = False

ble = get_ble_controller()
ble.connect()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2026-03-14 17:01:49,496 | INFO     |: Looking for Artemis Nano Peripheral Device: c0:81:c4:22:a9:64
# 2026-03-14 17:01:49,497 | INFO     |: Scanning for device with address: c0:81:c4:22:a9:64, service UUID: 789d254e-2393-4828-b10b-3952b9ca360b
# 2026-03-14 17:01:59,526 | INFO     |: Found 1 device(s) advertising service 789d254e-2393-4828-b10b-3952b9ca360b
# 2026-03-14 17:01:59,528 | INFO     |: Selecting device: 916E591F-7011-B7AC-55D0-A23622AFF175 (name: Artemis BLE)
# 2026-03-14 17:02:00,361 | INFO     |: Connected to c0:81:c4:22:a9:64

# %%
ble.send_command(CMD.PID_ORIENTATION, ""3000|45|1.0|0.0|0.0"")
s = ble.receive_string(ble.uuid['RX_STRING'])
print(s)
# Out:
# ORIENTATION_PID_STARTED,5000,90.000,1.000,0.000,0.000

# %%
ang_msgs = []

def angular_data_handler(uuid, byte_array):
    s = ble.bytearray_to_string(byte_array)
    ang_msgs.append(s)
    print(s)

ble.start_notify(ble.uuid["RX_STRING"], angular_data_handler)
ble.send_command(CMD.SEND_ANGULAR_DATA, "")
time.sleep(3)
ble.stop_notify(ble.uuid["RX_STRING"])

# %%
print("Number of messages:", len(ang_msgs))
print(ang_msgs[:10])
print(ang_msgs[-3:])
