# %%
# %load_ext autoreload
# %autoreload 2

from ble import get_ble_controller
from base_ble import LOG
from cmd_types import CMD
import time
import numpy as np

LOG.propagate = False
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ble = get_ble_controller()
ble.connect()
# Out:
# 2026-02-09 10:53:58,173 | INFO     |: Looking for Artemis Nano Peripheral Device: c0:81:b4:24:09:64
# 2026-02-09 10:53:58,174 | INFO     |: Scanning for device with address: c0:81:b4:24:09:64, service UUID: 854338fb-80c2-4675-9164-9deaf5c6b0ce
# 2026-02-09 10:54:08,204 | INFO     |: Found 1 device(s) advertising service 854338fb-80c2-4675-9164-9deaf5c6b0ce
# 2026-02-09 10:54:08,206 | INFO     |: Selecting device: 48BFACCB-F2FC-B972-B545-B20BBF6F1355 (name: Artemis BLE)
# 2026-02-09 10:54:09,175 | INFO     |: Connected to c0:81:b4:24:09:64

# %%
rx_lines = []

def handle_rx(uuid, value):
    s = value.decode("utf-8").strip()
    rx_lines.append(s)
    print(s)

# %%
ble.start_notify(ble.uuid["RX_STRING"], handle_rx)
ble.send_command(CMD.START_RP_LOG, "")
# Out:
# RP_LOG_STARTED
# RP_LOG_STOPPED,N=1659

# %%
ble.send_command(CMD.DUMP_RP_LOG, "")

# %%
ble.stop_notify(ble.uuid["RX_STRING"])

# %%
t_ms_list = []
pitch_list = []
roll_list = []

parsing = False
for s in rx_lines:
    s = s.strip()

    if s.startswith("t_ms,pitch_deg,roll_deg"):
        parsing = True
        continue

    if s.startswith("RP_DUMP_DONE"):
        break

    if parsing:
        parts = s.split(",")
        if len(parts) == 3:
            t_ms_list.append(int(parts[0]))
            pitch_list.append(float(parts[1]))
            roll_list.append(float(parts[2]))

t_ms = np.array(t_ms_list)
pitch = np.array(pitch_list)
roll = np.array(roll_list)

print("Parsed samples:", len(t_ms))
print("t_ms range:", t_ms[0], "->", t_ms[-1])
